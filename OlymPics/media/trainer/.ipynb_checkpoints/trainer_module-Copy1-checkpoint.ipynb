# %%
from clustimage import Clustimage
from PIL import Image
import cv2
import pickle

cl = Clustimage(method='pca')
# Out:
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]

# %%
img_add1 = './Test_image/test.jpg'
image = cv2.imread(img_add1,0)
cv2.imwrite('./Test_image/temp/test1.jpg',image)
# Out:
# True

# %%
face_results1= cl.extract_faces('./Test_image/temp/test1.jpg')
cl.plot_faces(faces=True, eyes=True)
# Out:
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 13.82it/s]

# %%
cl.load('clustimage_model1')
results_find = cl.find(face_results1['pathnames_face'], k=1, alpha=0.05, metric = 'euclidean')
# Out:
# [pypickle] Pickle file loaded: [clustimage_model1.pkl]
# [clustimage] >INFO> Load succesful!
# [clustimage] >INFO> Find similar images with metric [euclidean], k-nearest neighbors: 1 and under alpha: 0.05
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 417.34it/s]
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm   ] [0.00 sec] [RSS: 7.21085e-09] [loc=18010.563 scale=3979.229]
# [distfit] >INFO> [expon  ] [0.00 sec] [RSS: 2.77603e-07] [loc=0.000 scale=18010.563]
# [distfit] >INFO> [uniform] [0.00 sec] [RSS: 2.34902e-07] [loc=0.000 scale=41506.014]
# [pca] >Column labels are auto-completed.
# [distfit] >INFO> [gamma  ] [0.84 sec] [RSS: 5.01895e-09] [loc=-37440.370 scale=284.617]
# [distfit] >INFO> [t      ] [0.70 sec] [RSS: 8.55894e-09] [loc=18014.610 scale=3975.361]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [clustimage] >INFO> [1] similar images found for [4ff88592-dd42-43ee-b736-4318e703c02d.png]

# %%
cl.plot_find()
# Out:
# [clustimage] >INFO> [1] similar images detected for input image: [4ff88592-dd42-43ee-b736-4318e703c02d.png]

# %%
face_results = pickle.load(open('person_data1.pkl', 'rb'))

# %%
face_true_name = pickle.load(open('person_name.pkl', 'rb'))

# %%
name = list(results_find[list(results_find.keys())[1]]['y_pathnames'])
number = face_results['pathnames_face'].index(name)
print(number)
real = face_true_name[number+1]
print(real)
# Out:
# 23
# 3113

# %%
img = './result/' + 'img' + str(real)+ '.jpg'
img_A = Image.open(img)
img_add = './Test_image/test.jpg'
img_B = Image.open(img_add)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# %matplotlib inline

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_B)
ax[1].imshow(img_A)

# %%
face_truename = pickle.load(open('person_name.pkl', 'rb'))

# %%
face_truename.get(number)
# Out:
# '5788'

# %%
import pandas as pd

df1 = pd.read_csv('athletes.csv')
df2 = pd.read_csv('medals.csv')
print(df1)
print(df2)
# Out:
#       Index                                               Urls
# 0        15    https://olympics.com/en/athletes/michelle-gisin
# 1        24   https://olympics.com/en/athletes/galina-kulakova
# 2        25       https://olympics.com/en/athletes/laszlo-papp
# 3        51    https://olympics.com/en/athletes/yana-klochkova
# 4        53    https://olympics.com/en/athletes/dorothy-hamill
# ...     ...                                                ...
# 1261  12041  https://olympics.com/en/athletes/jasey-jay-and...
# 1262  12056  https://olympics.com/en/athletes/victoria-pend...
# 1263  12068   https://olympics.com/en/athletes/andre-de-grasse
# 1264  12090  https://olympics.com/en/athletes/alessandro-ha...
# 1265  12096          https://olympics.com/en/athletes/mima-ito
#
# [1266 rows x 2 columns]
#       discipline_title     slug_game                      event_title  \
# 0              Curling  beijing-2022                    Mixed Doubles
# 1              Curling  beijing-2022                    Mixed Doubles
# 2              Curling  beijing-2022                    Mixed Doubles
# 3              Curling  beijing-2022                    Mixed Doubles
# 4              Curling  beijing-2022                    Mixed Doubles
# ...                ...           ...                              ...
# 21692    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting   athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting   athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting   athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type participant_title  \
# 0            Mixed       GOLD         GameTeam             Italy
# 1            Mixed       GOLD         GameTeam             Italy
# 2            Mixed     SILVER         GameTeam            Norway
# 3            Mixed     SILVER         GameTeam            Norway
# 4            Mixed     BRONZE         GameTeam            Sweden
# ...            ...        ...              ...               ...
# 21692          Men     SILVER          Athlete               NaN
# 21693          Men     BRONZE          Athlete               NaN
# 21694          Men       GOLD          Athlete               NaN
# 21695          Men     SILVER          Athlete               NaN
# 21696          Men     BRONZE          Athlete               NaN
#
#                                              athlete_url  \
# 0      https://olympics.com/en/athletes/stefania-cons...
# 1          https://olympics.com/en/athletes/amos-mosaner
# 2      https://olympics.com/en/athletes/kristin-skaslien
# 3      https://olympics.com/en/athletes/magnus-nedreg...
# 4         https://olympics.com/en/athletes/almida-de-val
# ...                                                  ...
# 21692      https://olympics.com/en/athletes/viggo-jensen
# 21693                                                NaN
# 21694      https://olympics.com/en/athletes/viggo-jensen
# 21695  https://olympics.com/en/athletes/launceston-el...
# 21696   https://olympics.com/en/athletes/sotirios-versis
#
#              athlete_full_name   country_name country_code  \
# 0         Stefania CONSTANTINI          Italy           IT
# 1                 Amos MOSANER          Italy           IT
# 2             Kristin SKASLIEN         Norway           NO
# 3           Magnus NEDREGOTTEN         Norway           NO
# 4                Almida DE VAL         Sweden           SE
# ...                        ...            ...          ...
# 21692             Viggo JENSEN        Denmark           DK
# 21693  Alexandros Nikolopoulos         Greece           GR
# 21694             Viggo JENSEN        Denmark           DK
# 21695        Launceston ELLIOT  Great Britain           GB
# 21696          Sotirios VERSIS         Greece           GR
#
#       country_3_letter_code
# 0                       ITA
# 1                       ITA
# 2                       NOR
# 3                       NOR
# 4                       SWE
# ...                     ...
# 21692                   DEN
# 21693                   GRE
# 21694                   DEN
# 21695                   GBR
# 21696                   GRE
#
# [21697 rows x 12 columns]

# %%
result = df1.loc[df1['Index'] == 5788]
print(result['Urls'])
# Out:
# 584    https://olympics.com/en/athletes/isaquias-quei...
# Name: Urls, dtype: object

# %%
answer = df2.loc[df2['athlete_url'] == result['Urls'].iloc[0]]
answer
# Out:
#      discipline_title   slug_game                   event_title event_gender  \
# 480      Canoe Sprint  tokyo-2020      Men's Canoe Single 1000m          Men
# 2252     Canoe Sprint    rio-2016   C-1 200m (canoe single) men          Men
# 2268     Canoe Sprint    rio-2016  C-2 1000m (canoe double) men          Men
# 2275     Canoe Sprint    rio-2016  C-1 1000m (canoe single) men          Men
#
#      medal_type participant_type participant_title  \
# 480        GOLD          Athlete               NaN
# 2252     BRONZE          Athlete               NaN
# 2268     SILVER         GameTeam       Brazil team
# 2275     SILVER          Athlete               NaN
#
#                                             athlete_url  \
# 480   https://olympics.com/en/athletes/isaquias-quei...
# 2252  https://olympics.com/en/athletes/isaquias-quei...
# 2268  https://olympics.com/en/athletes/isaquias-quei...
# 2275  https://olympics.com/en/athletes/isaquias-quei...
#
#                 athlete_full_name country_name country_code  \
# 480   Isaquias QUEIROZ DOS SANTOS       Brazil           BR
# 2252  Isaquias QUEIROZ DOS SANTOS       Brazil           BR
# 2268  Isaquias QUEIROZ DOS SANTOS       Brazil           BR
# 2275  Isaquias QUEIROZ DOS SANTOS       Brazil           BR
#
#      country_3_letter_code
# 480                    BRA
# 2252                   BRA
# 2268                   BRA
# 2275                   BRA
