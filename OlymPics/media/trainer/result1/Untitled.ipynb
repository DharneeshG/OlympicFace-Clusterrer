# %%
from clustimage import Clustimage
from PIL import Image

# %%
cl = Clustimage(method='pca')
cl.load('clustimage_model')
# Out:
# [clustimage] >INFO> Load succesful!
# [pypickle] Pickle file loaded: [clustimage_model.pkl]

# %%
face_results1= cl.extract_faces('test1.jpg')
cl.plot_faces(faces=True, eyes=True)
# Out:
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 22.89it/s]

# %%
cl.load('clustimage_model')
results_find = cl.find(face_results1['pathnames_face'], k=1, alpha=0.05, metric = 'euclidean')
# Out:
# [clustimage] >INFO> Load succesful!
# [clustimage] >INFO> Find similar images with metric [euclidean], k-nearest neighbors: 1 and under alpha: 0.05
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 1061.85it/s]
# [pypickle] Pickle file loaded: [clustimage_model.pkl]
# [pca] >Column labels are auto-completed.
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm   ] [0.00 sec] [RSS: 7.2259e-09] [loc=18010.435 scale=3979.409]
# [distfit] >INFO> [expon  ] [0.00 sec] [RSS: 2.77555e-07] [loc=0.000 scale=18010.435]
# [distfit] >INFO> [uniform] [0.00 sec] [RSS: 2.34864e-07] [loc=0.000 scale=41507.354]
# [distfit] >INFO> [gamma  ] [0.62 sec] [RSS: 4.98456e-09] [loc=-38058.532 scale=280.658]
# [distfit] >INFO> [t      ] [0.62 sec] [RSS: 7.87564e-09] [loc=18034.461 scale=3986.414]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [clustimage] >INFO> [1] similar images found for [0330844c-8c85-4576-8bb9-0360e2aa0b38.png]

# %%
cl.plot_find()
# Out:
# [clustimage] >INFO> [1] similar images detected for input image: [0330844c-8c85-4576-8bb9-0360e2aa0b38.png]

# %%
cl.scatter(zoom=1)
# Out:
# [colourmap] >Add transparency to RGB colors (last column)
# [colourmap] >Add transparency to RGB colors (last column)
# [pca]> [WARNING]: De parameter <label> is deprecated and will not be supported in future version.
# [pca]> [WARNING]: De parameter <y> is deprecated and will not be supported in future version. Use <labels> instead.
# (None,
#  <AxesSubplot:title={'center':'180 Principal Components explain [95.10%] of the variance'}, xlabel='PC1 (14.1% expl.var)', ylabel='PC2 (9.54% expl.var)'>)

# %%
name = list(results_find[list(results_find.keys())[1]]['y_pathnames'])
number = face_results['pathnames_face'].index(name)
print(number)
# print(face_results['pathnames_face'].index(name))
# # Image.open(img)

# img = 'image' + str(face_results['filenames'][725])
# img_A = Image.open(img)
# img_B = Image.open('test.jpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-bbd21403331e> in <module>
#       1 name = list(results_find[list(results_find.keys())[1]]['y_pathnames'])
# ----> 2 number = face_results['pathnames_face'].index(name)
#       3 print(number)
#       4 # print(face_results['pathnames_face'].index(name))
#       5 # # Image.open(img)
#
# NameError: name 'face_results' is not defined
